# %%
# Task 1. RGB to HSV function.

# %%
import skimage
import numpy as np

# %%
from skimage import io
image = io.imread('cat1.jpg')

# %%
image
# Out:
# array([[[104, 128,  16],
#         [101, 125,  13],
#         [ 98, 122,  10],
#         ...,
#         [ 62,  53,  24],
#         [ 70,  59,  27],
#         [ 74,  61,  27]],
#
#        [[103, 127,  15],
#         [101, 125,  13],
#         [ 98, 122,  10],
#         ...,
#         [ 64,  55,  26],
#         [ 71,  60,  28],
#         [ 80,  67,  33]],
#
#        [[102, 126,  12],
#         [101, 125,  11],
#         [ 98, 122,   8],
#         ...,
#         [ 64,  55,  26],
#         [ 71,  60,  28],
#         [ 81,  68,  34]],
#
#        ...,
#
#        [[ 87,  83,  58],
#         [ 75,  71,  46],
#         [ 67,  63,  38],
#         ...,
#         [ 41,  37,   8],
#         [ 46,  42,  13],
#         [ 56,  50,  24]],
#
#        [[123, 112,  92],
#         [116, 105,  85],
#         [115, 107,  86],
#         ...,
#         [ 40,  22,   2],
#         [ 41,  23,   3],
#         [ 46,  25,   8]],
#
#        [[116, 103,  84],
#         [121, 108,  89],
#         [136, 125, 107],
# ...

# %%
image.shape
# Out:
# (2000, 1273, 3)

# %%
def func_to_hsv(image):
    new_image = np.zeros(image.shape)
    for x in range(image.shape[0]):
        for y in range(image.shape[1]):
                r = image[x,y,0]/255
                g = image[x,y,1]/255
                b = image[x,y,2]/255
                maxx = max(r,g,b)
                minn = min(r,g,b)
                delta = maxx - minn

                if delta == 0:
                    h = 0
                elif maxx == r:
                    h = (60 * ((g-b)/delta) + 360) % 360
                elif maxx == g:
                    h = (60 * ((b-r)/delta) + 120) % 360
                elif maxx == b:
                    h = (60 * ((r-g)/delta) + 240) % 360
                v = maxx
                if maxx == 0:
                    s = 0
                else:
                    s = delta/maxx

                new_image[x,y] = [(h/360), (s), (v)]

    return new_image

# %%
hsv_func = func_to_hsv(image)

# %%
io.imshow(hsv_func)

# %%
from skimage import io, color, data
image = io.imread('cat1.jpg')
image_hsv = color.rgb2hsv(image)

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(15,5))
# original = plt.subplot(1,3,1)
# io.imshow(image)
# original.set_title("original image")

rgb2hsv_function = plt.subplot(1,3,2)
io.imshow(hsv_func)
rgb2hsv_function.set_title("rgb2hsv function")

rgb2hsv_skimage_function = plt.subplot(1,3,3)
io.imshow(image_hsv)
rgb2hsv_skimage_function.set_title("rgb2hsv skimage function")
# Out:
# Text(0.5, 1.0, 'rgb2hsv skimage function')

# %%
# Task 2. Controlling the contrast and brightness.

# %%
import cv2
import numpy as np
from skimage import io

# %%
image = io.imread('cat1.jpg')

# %%
new_image1 = np.zeros(image.shape, image.dtype)

# %%
brightness = -10
contrast = 10

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image1[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image2 = np.zeros(image.shape, image.dtype)

# %%
brightness = -5
contrast = 10

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image2[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image3 = np.zeros(image.shape, image.dtype)

# %%
brightness = 0
contrast = 10

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image3[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image4 = np.zeros(image.shape, image.dtype)

# %%
brightness = 5
contrast = 10

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image4[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image5 = np.zeros(image.shape, image.dtype)

# %%
brightness = 10
contrast = 10

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image5[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image6 = np.zeros(image.shape, image.dtype)

# %%
brightness = -10
contrast = 5

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image6[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image7 = np.zeros(image.shape, image.dtype)

# %%
brightness = -5
contrast = 5

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image7[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image8 = np.zeros(image.shape, image.dtype)

# %%
brightness = 0
contrast = 5

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image8[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image9 = np.zeros(image.shape, image.dtype)

# %%
brightness = 5
contrast = 5

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image9[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image10 = np.zeros(image.shape, image.dtype)

# %%
brightness = 10
contrast = 5

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image10[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image11 = np.zeros(image.shape, image.dtype)

# %%
brightness = -10
contrast = 0

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image11[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image12 = np.zeros(image.shape, image.dtype)

# %%
brightness = -5
contrast = 0

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image12[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image13 = np.zeros(image.shape, image.dtype)

# %%
brightness = 0
contrast = 0

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image13[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image14 = np.zeros(image.shape, image.dtype)

# %%
brightness = 5
contrast = 0

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image14[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image15 = np.zeros(image.shape, image.dtype)

# %%
brightness = 10
contrast = 0

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image15[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image16 = np.zeros(image.shape, image.dtype)

# %%
brightness = -10
contrast = -5

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image16[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image17 = np.zeros(image.shape, image.dtype)

# %%
brightness = -5
contrast = -5

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image17[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image18 = np.zeros(image.shape, image.dtype)

# %%
brightness = 0
contrast = -5

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image18[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image19 = np.zeros(image.shape, image.dtype)

# %%
brightness = 5
contrast = -5

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image19[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image20 = np.zeros(image.shape, image.dtype)

# %%
brightness = 10
contrast = -5

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image20[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image21 = np.zeros(image.shape, image.dtype)

# %%
brightness = -10
contrast = -10

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image21[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image22 = np.zeros(image.shape, image.dtype)

# %%
brightness = -5
contrast = -10

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image22[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image23 = np.zeros(image.shape, image.dtype)

# %%
brightness = 0
contrast = -10

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image23[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image24 = np.zeros(image.shape, image.dtype)

# %%
brightness = 5
contrast = -10

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image24[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
new_image25 = np.zeros(image.shape, image.dtype)

# %%
brightness = 10
contrast = -10

for y in range(image.shape[0]):
    for x in range(image.shape[1]):
        for c in range(image.shape[2]):
            new_image25[y,x,c] = np.clip(contrast * image[y,x,c] + brightness, 0, 255)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
ax1 = fig.add_subplot(5,5,1)
ax1.imshow(new_image1)

ax2 = fig.add_subplot(5,5,2)
ax2.imshow(new_image2)

ax3 = fig.add_subplot(5,5,3)
ax3.imshow(new_image3)

ax4 = fig.add_subplot(5,5,4)
ax4.imshow(new_image4)

ax5 = fig.add_subplot(5,5,5)
ax5.imshow(new_image5)

ax6 = fig.add_subplot(5,5,6)
ax6.imshow(new_image6)

ax7 = fig.add_subplot(5,5,7)
ax7.imshow(new_image7)

ax8 = fig.add_subplot(5,5,8)
ax8.imshow(new_image8)

ax9 = fig.add_subplot(5,5,9)
ax9.imshow(new_image9)

ax10 = fig.add_subplot(5,5,10)
ax10.imshow(new_image10)

ax11 = fig.add_subplot(5,5,11)
ax11.imshow(new_image11)

ax12 = fig.add_subplot(5,5,12)
ax12.imshow(new_image12)

ax13 = fig.add_subplot(5,5,13)
ax13.imshow(new_image13)

ax14 = fig.add_subplot(5,5,14)
ax14.imshow(new_image14)

ax15 = fig.add_subplot(5,5,15)
ax15.imshow(new_image15)

ax16 = fig.add_subplot(5,5,16)
ax16.imshow(new_image16)

ax17 = fig.add_subplot(5,5,17)
ax17.imshow(new_image17)

ax18 = fig.add_subplot(5,5,18)
ax18.imshow(new_image18)

ax19 = fig.add_subplot(5,5,19)
ax19.imshow(new_image19)

ax20 = fig.add_subplot(5,5,20)
ax20.imshow(new_image20)

ax21 = fig.add_subplot(5,5,21)
ax21.imshow(new_image21)

ax22 = fig.add_subplot(5,5,22)
ax22.imshow(new_image22)

ax23 = fig.add_subplot(5,5,23)
ax23.imshow(new_image23)

ax24 = fig.add_subplot(5,5,24)
ax24.imshow(new_image24)

ax25 = fig.add_subplot(5,5,25)
ax25.imshow(new_image25)

# %%
# Task 3. Apply Filters to blur the image and find the one that keeps the most information.

# %%
import numpy as np
from skimage import io, color, data
import cv2
from skimage.metrics import structural_similarity

# %%
image_cat = io.imread('cat2.jpg')

# %%
image_grey =cv2.cvtColor(image_cat, cv2.COLOR_BGR2GRAY)
median_image = cv2.medianBlur(image_grey,5)
bilateral_image = cv2.bilateralFilter(image_grey, 2,100,50)
gauss_image = cv2.GaussianBlur(image_grey, (5,5), cv2.BORDER_DEFAULT)

# %%
ssim_original = structural_similarity(image_grey, image_grey, data_range=image_grey.max() - image_grey.min(), multichannel=True)
ssim_median = structural_similarity(image_grey, median_image, data_range=image_grey.max() - image_grey.min(), multichannel=True)
ssim_bilateral = structural_similarity(image_grey, bilateral_image, data_range=image_grey.max() - image_grey.min(), multichannel=True)
ssim_gauss = structural_similarity(image_grey, gauss_image, data_range=image_grey.max() - image_grey.min(), multichannel=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure(figsize=(12,20))
orig = plt.subplot(1,4,1)
io.imshow(image_grey)
orig.set_title(ssim_original)

median = plt.subplot(1,4,2)
io.imshow(median_image)
median.set_title(ssim_median)

bilateral = plt.subplot(1,4,3)
io.imshow(bilateral_image)
bilateral.set_title(ssim_bilateral)

gauss = plt.subplot(1,4,4)
io.imshow(gauss_image)
gauss.set_title(ssim_gauss)
# Out:
# Text(0.5, 1.0, '0.8841656689413607')

# %%
# Task 4. Eye detection application.

# %%
import cv2

camera = cv2.VideoCapture(0)

eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")

while True:
    ret, frame = camera.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    eyes = eye_cascade.detectMultiScale(gray, 1.2, 5, minSize=(10, 10), flags=cv2.CASCADE_SCALE_IMAGE)

    for (x, y, w, h) in eyes:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 245, 67), 2)

    cv2.imshow("Video Frame", frame)

    if cv2.waitKey(1) == ord('q'):
        break

camera.release()
cv2.destroyAllWindows()
